# %% [markdown]
# # 00. Install packages and mount drive

# %%
from google.colab import drive
import pandas as pd

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install openai
# !pip install librosa soundfile
# !pip install mutagen
# !pip install librosa pydub
# !pip install --upgrade typing_extensions

# %% [markdown]
# # 01. Public sample Cases database

# %%
# Step 2: Import necessary libraries
import os
import pandas as pd

# Step 3: Define the folder path
folder_path = '/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES'

# Step 4: List all files in the directory
files = os.listdir(folder_path)

# Step 5: Filter out MP3 files
mp3_files = [file for file in files if file.endswith('.mp3')]

# Step 6: Create a DataFrame with the MP3 files
case_df = pd.DataFrame(mp3_files, columns=['File Name'])

# Step 7: Display the DataFrame
case_df
# Out:
#                                             File Name
# 0   ACPA 2 more in grammar school, and out little ...
# 1   ACPA and I started out on the switch board and...
# 2               ACPA playing in the snow is fun-3.mp3
# 3                     Facebook (pick up the baby).mp3
# 4   ACPA oh let me see, what can I tell you about ...
# ..                                                ...
# 91                              Video 3_5 (muddy).mp3
# 92                                Video 6_1 (mom).mp3
# 93                             Video 1_4 (seesaw).mp3
# 94                              Video 6_5 (bobby).mp3
# 95                              Video 2_4 (daddy).mp3
#
# [96 rows x 1 columns]

# %%
# call each file
case_df['File Name'][0]
# Out:
# 'ACPA 2 more in grammar school, and out little 3 year old.mp3'

# %% [markdown]
# # 02. Playing Audio file

# %%
import os
from IPython.display import Audio

# Define the folder path
folder_path = '/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES'

# List all files in the directory
files = os.listdir(folder_path)

# Filter out MP3 files
mp3_files = [file for file in files if file.endswith('.mp3')]

# Define a function to play audio with descriptions
def play_audio_with_description(file_name):
    file_path = os.path.join(folder_path, file_name)
    print(f"Playing file: {file_name}\n\n")  # Display the file name or any other description
    display(Audio(file_path))

# Example: Play a specific file with its description
play_audio_with_description(mp3_files[0])
# Out:
# Playing file: ACPA 2 more in grammar school, and out little 3 year old.mp3
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
original_audiofile = play_audio_with_description(mp3_files[0])
original_audiofile
# Out:
# Playing file: ACPA 2 more in grammar school, and out little 3 year old.mp3
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 03. Whisper model

# %% [markdown]
# ## Free Whisper version

# %%
import whisper
model = whisper.load_model("base")  # You can replace "base" with "small", "medium", "large", etc.
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 92.0MiB/s]

# %%
# call each file
case_df['File Name'][0]
# Out:
# 'ACPA 2 more in grammar school, and out little 3 year old.mp3'

# %%
result = model.transcribe("/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES/ACPA 2 more in grammar school, and out little 3 year old.mp3")
print("\n\n\n")
print("Original file name: ",case_df['File Name'][0])
print("Generated Output:   ",result["text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Original file name:  ACPA 2 more in grammar school, and out little 3 year old.mp3
# Generated Output:     Come on, where we're going? I'm a little through here.

# %% [markdown]
# ## OpenAI paid version

# %%
#https://platform.openai.com/docs/guides/speech-to-text/longer-inputs

import os
import openai

import os
os.environ["OPENAI_API_KEY"] = "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"

# Initialize the OpenAI client
client = openai.Client()

# Define the file path to your audio file
file_path = "/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES/ACPA 2 more in grammar school, and out little 3 year old.mp3"
#file_path = ("/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES/", case_df['File Name'][0])

# Open the audio file
with open(file_path, "rb") as audio_file:
    # Create the transcription
    transcript = client.audio.transcriptions.create(
        model="whisper-1",
        file=audio_file,
        response_format="text"
    )

# Print the transcript
print("Original File Name: ", case_df['File Name'][0])
print("Whisper Output:     ",transcript)
# Out:
# Original File Name:  ACPA 2 more in grammar school, and out little 3 year old.mp3
# Whisper Output:      We're in grammar school and I'm a three-year-old.

# %% [markdown]
# ## Language Translation version

# %%
import openai

import os
os.environ["OPENAI_API_KEY"] = "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"

# Initialize the OpenAI client
client = openai.Client()

# Define the file path to your audio file
file_path = "/content/drive/MyDrive/VUMC_postcleft/PUBLIC SAMPLES/CASES/ACPA 2 more in grammar school, and out little 3 year old.mp3"


# Open the audio file
with open(file_path, "rb") as audio_file:
    # Create the transcription
    transcript = client.audio.translations.create(
        model="whisper-1",
        file=audio_file,
        response_format="text"
    )

# Print the transcript
print("Original File Name: ", case_df['File Name'][0])
print("Whisper Output:     ",transcript)
# Out:
# Original File Name:  ACPA 2 more in grammar school, and out little 3 year old.mp3
# Whisper Output:      We're in grammar school and I'm a three-year-old.
